# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r"https://raw.githubusercontent.com/dsrscientist/DSData/master/happiness_score_dataset.csv")
df
# Out:
#                       Country                           Region  \
# 0                 Switzerland                   Western Europe
# 1                     Iceland                   Western Europe
# 2                     Denmark                   Western Europe
# 3                      Norway                   Western Europe
# 4                      Canada                    North America
# 5                     Finland                   Western Europe
# 6                 Netherlands                   Western Europe
# 7                      Sweden                   Western Europe
# 8                 New Zealand        Australia and New Zealand
# 9                   Australia        Australia and New Zealand
# 10                     Israel  Middle East and Northern Africa
# 11                 Costa Rica      Latin America and Caribbean
# 12                    Austria                   Western Europe
# 13                     Mexico      Latin America and Caribbean
# ...

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
import seaborn as sns
sns.scatterplot(x='Country',y='Happiness Rank',data=df)

# %%
import seaborn as sns
sns.scatterplot(x='Region',y='Happiness Rank',data=df)

# %%
import seaborn as sns
sns.scatterplot(x='Happiness Score',y='Happiness Rank',data=df)

# %%
import seaborn as sns
sns.scatterplot(x='Standard Error',y='Happiness Rank',data=df)

# %%
import seaborn as sns
sns.scatterplot(x='Economy (GDP per Capita)',y='Happiness Rank',data=df)

# %%
import seaborn as sns
sns.scatterplot(x='Family',y='Happiness Rank',data=df)

# %%
import seaborn as sns
sns.scatterplot(x='Health (Life Expectancy)',y='Happiness Rank',data=df)

# %%
import seaborn as sns
sns.scatterplot(x='Freedom',y='Happiness Rank',data=df)

# %%
import seaborn as sns
sns.scatterplot(x='Trust (Government Corruption)',y='Happiness Rank',data=df)

# %%
import seaborn as sns
sns.scatterplot(x='Generosity',y='Happiness Rank',data=df)

# %%
import seaborn as sns
sns.scatterplot(x='Dystopia Residual',y='Happiness Rank',data=df)

# %%
df.corr()
# Out:
#                                Happiness Rank  Happiness Score  \
# Happiness Rank                       1.000000        -0.992105
# Happiness Score                     -0.992105         1.000000
# Standard Error                       0.158516        -0.177254
# Economy (GDP per Capita)            -0.785267         0.780966
# Family                              -0.733644         0.740605
# Health (Life Expectancy)            -0.735613         0.724200
# Freedom                             -0.556886         0.568211
# Trust (Government Corruption)       -0.372315         0.395199
# Generosity                          -0.160142         0.180319
# Dystopia Residual                   -0.521999         0.530474
#
#                                Standard Error  Economy (GDP per Capita)  \
# Happiness Rank                       0.158516                 -0.785267
# Happiness Score                     -0.177254                  0.780966
# ...

# %%
df.corr()['Happiness Rank'].sort_values()
# Out:
# Happiness Score                 -0.992105
# Economy (GDP per Capita)        -0.785267
# Health (Life Expectancy)        -0.735613
# Family                          -0.733644
# Freedom                         -0.556886
# Dystopia Residual               -0.521999
# Trust (Government Corruption)   -0.372315
# Generosity                      -0.160142
# Standard Error                   0.158516
# Happiness Rank                   1.000000
# Name: Happiness Rank, dtype: float64

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15,7))
sns.heatmap(df.corr(),annot=True, linewidths=0.5,linecolor='black',fmt='.2f')

# %% [raw]
# Hapiness Score has a 99% correlation with Happiness Rank column which can be considered as a strongest bond
# Standard Error has a 16% correlation with Happiness Rank column which can be considered as a weak bond
# Economy(GDP Peer capita) has a 79% correlation with Happiness Rank column which can be considered as a strong bond
# Family has a 73% correlation with Happiness Rank column which can be considered as a strong bond
# Health(Life expectanccy) has a 74% correlation with Happiness Rank column which can be considered as a strong bond
# Freedom has a 56% correlation with Happiness Rank column which can be considered as a good bond
# Trust (government Curruption) has a 37% correlation with Happiness Rank column which can be considered as a good bond
# Generosity has a 17% correlation with Happiness Rank column which can be considered as a weak bond
# Dystopia Residual has a 52% correlation with Happiness Rank column which can be considered as a strong bond

# %%
df.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %%
plt.figure(figsize=(15,12))
sns.heatmap(round(df.describe()[1:].transpose(),2),linewidth=2,annot=True,fmt='f')
plt.xticks(fontsize=18)
plt.yticks(fontsize=12)
plt.title("Variables summary")
plt.show()

# %% [raw]
# Describing the outcomes of above plotings
# Happiness Score-
# mean-5.380000
# std- 1.150000
# max-7.590000
# min-2.840000
#
# Standard Error
# mean-0.050000
# std- 0.020000
# max-0.140000
# min-0.02000
#
# Economy GDP Per Capita-
# mean-0.850000
# std- 0.400000
# max-1.690000
# min-0.00000
#
# Family-
# mean-0.990000
# std- 0.270000
# max-1.400000
# min-0.00000
#
# Health(Life Expectancy)-
# mean-0.630000
# std- 0.250000
# max-1.030000
# min-0.00000
#
# Freedom-
# mean-0.430000
# std- 0.150000
# max-0.670000
# min-0.00000
#
# Trust(Government Curruption)-
# mean-0.140000
# std- 0.120000
# max-0.550000
# min-0.00000
#
# Generosity-
# mean-0.240000
# std- 0.130000
# max-0.800000
# min-0.00000
#
# Dystopia Residual-
# mean-2.100000
# std- 0.550000
# min-0.330000
# max-3.60000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
# Country                          158 non-null object
# Region                           158 non-null object
# Happiness Rank                   158 non-null int64
# Happiness Score                  158 non-null float64
# Standard Error                   158 non-null float64
# Economy (GDP per Capita)         158 non-null float64
# Family                           158 non-null float64
# Health (Life Expectancy)         158 non-null float64
# Freedom                          158 non-null float64
# Trust (Government Corruption)    158 non-null float64
# Generosity                       158 non-null float64
# Dystopia Residual                158 non-null float64
# dtypes: float64(9), int64(1), object(2)
# memory usage: 13.6+ KB

# %% [markdown]
# ## Outliers checking:

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.preprocessing import LabelEncoder
for column in df:
    if df[column].dtypes == 'object':
        encoder = LabelEncoder()
        df[column] = encoder.fit_transform(df[column])
df
# Out:
#      Country  Region  Happiness Rank  Happiness Score  Standard Error  \
# 0        135       9               1            7.587         0.03411
# 1         58       9               2            7.561         0.04884
# 2         37       9               3            7.527         0.03328
# 3        105       9               4            7.522         0.03880
# 4         24       5               5            7.427         0.03553
# 5         45       9               6            7.406         0.03140
# 6         99       9               7            7.378         0.02799
# 7        134       9               8            7.364         0.03157
# 8        100       0               9            7.286         0.03371
# 9          6       0              10            7.284         0.04083
# 10        64       4              11            7.278         0.03470
# 11        33       3              12            7.226         0.04454
# ...

# %%
graph=1
plt.figure(figsize=(10,10))
for column in df:
    plt.subplot(4,3,graph)
  
    sns.boxplot(df[column],color='green',orient='h')
    plt.xlabel(column,fontsize=10)
    graph+=1
    plt.tight_layout()

# %%
from sklearn.preprocessing import LabelEncoder
graph = 1
plt.figure(figsize=(10,10),facecolor='yellow')
for column in df:

    plt.subplot(4,3,graph)
    sns.boxplot(df[column],color='green',orient='v')
    plt.xlabel(column,fontsize=10)
    graph+=1
    plt.tight_layout()

# %% [markdown]
# ## Skewnwess:

# %%
df.skew()
# Out:
# Country                          0.000000
# Region                          -0.116119
# Happiness Rank                   0.000418
# Happiness Score                  0.097769
# Standard Error                   1.983439
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    1.385463
# Generosity                       1.001961
# Dystopia Residual               -0.238911
# dtype: float64

# %%
Outcome of the skewness= Skewness threshold is taken as +/-0.65. Columns which are having skewness:
Country                       
Region                         
Happiness Rank  
Standard Error                   
Economy (GDP per Capita)       
Family                          
Health (Life Expectancy)        
Freedom                         
Trust (Government Corruption)    
Generosity                       
Dystopia Residual

# %%
sns.distplot(df['Country'])

# %%
sns.distplot(df['Region'])

# %%
sns.distplot(df['Happiness Rank'])

# %%
sns.distplot(df['Standard Error'])

# %%
sns.distplot(df['Economy (GDP per Capita)'])

# %%
sns.distplot(df['Family'])

# %%
sns.distplot(df['Health (Life Expectancy)'])

# %%
sns.distplot(df['Freedom'])

# %%
sns.distplot(df['Trust (Government Corruption)'])

# %%
sns.distplot(df['Generosity'])

# %%
sns.distplot(df['Dystopia Residual'])

# %% [markdown]
# ## Data Cleansing

# %%
df.corr()['Happiness Rank']
# Out:
# Country                         -0.098538
# Region                           0.213773
# Happiness Rank                   1.000000
# Happiness Score                 -0.992105
# Standard Error                   0.158516
# Economy (GDP per Capita)        -0.785267
# Family                          -0.733644
# Health (Life Expectancy)        -0.735613
# Freedom                         -0.556886
# Trust (Government Corruption)   -0.372315
# Generosity                      -0.160142
# Dystopia Residual               -0.521999
# Name: Happiness Rank, dtype: float64

# %% [markdown]
# # Removing Outliers:

# %% [raw]
# Z-score Technique

# %%
from scipy.stats import zscore
import numpy as np
z=np.abs(zscore(df))
z.shape
# Out:
# (158, 12)

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([ 27,  40,  64, 115, 128, 147, 153, 155, 157], dtype=int32), array([ 9,  4,  4,  4, 10,  6,  9, 11,  6], dtype=int32))

# %%
len(np.where(z>3)[0])
# Out:
# 9

# %%
df_new=df[(z<3).all(axis=1)]
print("old DataFrame",df.shape)
print("New DataFrame",df_new.shape)
print("total_dropped_rows",df.shape[0]-df_new.shape[0])
# Out:
# old DataFrame (158, 12)
# New DataFrame (149, 12)
# total_dropped_rows 9

# %%
loss_percent=(158-149)/158*100
print(loss_percent,"%")
# Out:
# 5.69620253164557 %

# %% [markdown]
# ## Model without outlieer  is df and model wwith ddesired outliers is df_new1:

# %%
x=df_new.iloc[:,:-1]
y=df_new.iloc[:,-1]

# %% [markdown]
# ## Transforming data to remove skewness:

# %%
from sklearn.preprocessing import PowerTransformer
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-81-088119f05645> in <module>()
# ----> 1 from sklearn.preprocessing import PowerTransformer
#
# ImportError: cannot import name 'PowerTransformer' from 'sklearn.preprocessing' (D:\conda\lib\site-packages\sklearn\preprocessing\__init__.py)
