# %% [markdown]
# # Red Wine quality Prediction

# %% [markdown]
# # Problem Statement

# %% [markdown]
# Problem Statement:
# The dataset is related to red and white variants of the Portuguese "Vinho Verde" wine. Due to privacy and logistic issues, only physicochemical (inputs) and sensory (the output) variables are available (e.g. there is no data about grape types, wine brand, wine selling price, etc.).
#
# This dataset can be viewed as classification task. The classes are ordered and not balanced (e.g. there are many more normal wines than excellent or poor ones). Also, we are not sure if all input variables are relevant. So it could be interesting to test feature selection methods.

# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv(r'https://raw.githubusercontent.com/dsrscientist/DSData/master/winequality-red.csv')
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6      0.069
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            7.5              0.50         0.36             6.1      0.071
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# ## Heatmap

# %%
sns.heatmap(df.isnull(), cmap='Greens_r')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Data Explorattion

# %%
  sns.distplot(df['fixed acidity'], bins=20)
# Out:
# <AxesSubplot:xlabel='fixed acidity', ylabel='Density'>

# %%
sns.lmplot(x='fixed acidity', y='quality', data=df)
plt.title('Wine quality vs fixed acidity')
plt.show()

# %%
 sns.lmplot(x='volatile acidity', y='quality', data=df)
plt.title('Wine quality vs volatile acidity')
plt.show()

# %%
sns.lmplot(x='citric acid', y='quality', data=df)
plt.title('Wine quality vs citric acid')
plt.show()

# %%
sns.lmplot(x='residual sugar', y='quality', data=df)
plt.title('Wine quality vs residual sugar')
plt.show()

# %%
sns.lmplot(x='chlorides', y='quality', data=df)
plt.title('Wine quality vs residual sugar')
plt.show()

# %%
sns.lmplot(x='free sulfur dioxide', y='quality', data=df)
plt.title('Wine quality vs free sulfur dioxide')
plt.show()

# %%
sns.lmplot(x='total sulfur dioxide', y='quality', data=df)
plt.title('Wine quality vs total sulfur dioxide')
plt.show()

# %%
sns.violinplot(data=df,x='density',color='teal')
# Out:
# <AxesSubplot:xlabel='density'>

# %% [markdown]
# It shows the maximum and minimum density at 0.996/0.998 and 0.990/1.004 respectively

# %%
sns.scatterplot(x='density', y='quality',data=df,palette='deep',color='teal')
# Out:
# <AxesSubplot:xlabel='density', ylabel='quality'>

# %%
sns.scatterplot(x='pH', y='quality',data=df,palette='deep',color='teal')
# Out:
# <AxesSubplot:xlabel='pH', ylabel='quality'>

# %%
sns.distplot(df['pH'],rug=True, color='red')
# Out:
# <AxesSubplot:xlabel='pH', ylabel='Density'>

# %%
sns.violinplot(data=df,x='sulphates',color='teal')
# Out:
# <AxesSubplot:xlabel='sulphates'>

# %%
sns.histplot(data=df,x= 'sulphates',y='quality', color='green', fill= True, binwidth=0.4)
plt.title("Wine quality vs sulphates")
plt.show()

# %%
sns.scatterplot(x='alcohol', y='quality',data=df,palette='deep',color='teal')
# Out:
# <AxesSubplot:xlabel='alcohol', ylabel='quality'>

# %% [markdown]
# Increased alcohol content leads to increased wine quality

# %%
sns.pairplot(data=df, size=1)

# %% [markdown]
# ## Correlation Matrix

# %%
df.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
df.corr()["quality"].sort_values()
# Out:
# volatile acidity       -0.390558
# total sulfur dioxide   -0.185100
# density                -0.174919
# chlorides              -0.128907
# pH                     -0.057731
# free sulfur dioxide    -0.050656
# residual sugar          0.013732
# fixed acidity           0.124052
# citric acid             0.226373
# sulphates               0.251397
# alcohol                 0.476166
# quality                 1.000000
# Name: quality, dtype: float64

# %% [markdown]
# ## Correlation Heatmap

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(13,8))
sns.heatmap(df.corr(),annot= True, linewidths=0.5,linecolor='blue',fmt='2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Observations-
#
#
# fixed acidity is 12% correlated to quality which is  good
#
# volatile acidity is -39% correlated to quality  which is very bad
#
# citric acid is 23% correlated to quality  which is good
#
# residual sugar is 1.4% correlated to quality  which is bad
#
# chlorides is 23% correlated to quality which is good bad
#
# free sulfur dioxide is 1.4% correlated to quality which is bad
#
# total sulfur dioxideis -13% correlated to quality which is very bad
#
# density is -19% correlated to quality which is very bad
#
# pH is 5.8% correlated to quality which is  bad
#
# sulphates is 25% correlated to quality which is good
#
# alcohol is 48% correlated to quality which is very good

# %%
plt.figure(figsize=(13,8))
sns.heatmap(df.cov(), annot=True, cmap='CMRmap')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Data desscription

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
plt.figure(figsize=(15,7))
sns.heatmap(round(df.describe()[1:].transpose(),2), linewidth=1.5, fmt='f', annot= True)
plt.xticks(fontsize=18)
plt.yticks(fontsize=12)
plt.title('variable summary')
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %% [markdown]
# ## Outliers

# %%
sns.boxplot(df.alcohol, orient='h', color='green')
# Out:
# <AxesSubplot:xlabel='alcohol'>

# %%
sns.boxplot(df.chlorides, orient='h', color='green')
# Out:
# <AxesSubplot:xlabel='chlorides'>

# %%
from sklearn.preprocessing import LabelEncoder
graph = 1
plt.figure(figsize=(10,10),facecolor='yellow')
for column in df:

    plt.subplot(4,3,graph)
    sns.boxplot(df[column],color='green',orient='v')
    plt.xlabel(column,fontsize=10)
    graph+=1
    plt.tight_layout()

# %% [markdown]
# ## Skewness in dataset

# %%
df.skew()
# Out:
# fixed acidity           0.982751
# volatile acidity        0.671593
# citric acid             0.318337
# residual sugar          4.540655
# chlorides               5.680347
# free sulfur dioxide     1.250567
# total sulfur dioxide    1.515531
# density                 0.071288
# pH                      0.193683
# sulphates               2.428672
# alcohol                 0.860829
# quality                 0.217802
# dtype: float64

# %% [markdown]
# Threshold value= +/-0.65

# %%
sns.distplot(df['fixed acidity'])
# Out:
# <AxesSubplot:xlabel='fixed acidity', ylabel='Density'>

# %%
sns.distplot(df['volatile acidity'])
# Out:
# <AxesSubplot:xlabel='volatile acidity', ylabel='Density'>

# %%
sns.distplot(df['citric acid'])
# Out:
# <AxesSubplot:xlabel='citric acid', ylabel='Density'>

# %%
sns.distplot(df['residual sugar'])
# Out:
# <AxesSubplot:xlabel='residual sugar', ylabel='Density'>

# %%
sns.distplot(df['chlorides'])
# Out:
# <AxesSubplot:xlabel='chlorides', ylabel='Density'>

# %%
sns.distplot(df['free sulfur dioxide'])
# Out:
# <AxesSubplot:xlabel='free sulfur dioxide', ylabel='Density'>

# %%
sns.distplot(df['total sulfur dioxide'])
# Out:
# <AxesSubplot:xlabel='total sulfur dioxide', ylabel='Density'>

# %%
sns.distplot(df['density'])
# Out:
# <AxesSubplot:xlabel='density', ylabel='Density'>

# %%
sns.distplot(df['pH'])
# Out:
# <AxesSubplot:xlabel='pH', ylabel='Density'>

# %%
sns.distplot(df['sulphates'])
# Out:
# <AxesSubplot:xlabel='sulphates', ylabel='Density'>

# %%
sns.distplot(df['alcohol'])
# Out:
# <AxesSubplot:xlabel='alcohol', ylabel='Density'>

# %% [markdown]
# As we can observe that the distribution is not normally distributed and hence skewness is present in the data

# %% [markdown]
# ## Data Cleansing

# %%
df.corr()['quality']
# Out:
# fixed acidity           0.124052
# volatile acidity       -0.390558
# citric acid             0.226373
# residual sugar          0.013732
# chlorides              -0.128907
# free sulfur dioxide    -0.050656
# total sulfur dioxide   -0.185100
# density                -0.174919
# pH                     -0.057731
# sulphates               0.251397
# alcohol                 0.476166
# quality                 1.000000
# Name: quality, dtype: float64

# %% [markdown]
# ## Removing Outliers

# %%
from scipy.stats import zscore
import numpy as np
z=np.abs(zscore(df))
z.shape
# Out:
# (1599, 12)

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([  13,   14,   15,   15,   17,   17,   19,   33,   38,   42,   43,
#          45,   57,   81,   81,   83,   86,   88,   91,   92,   95,  106,
#         106,  109,  120,  126,  127,  142,  144,  147,  151,  151,  151,
#         151,  163,  164,  169,  169,  181,  199,  226,  226,  240,  243,
#         244,  258,  258,  274,  281,  291,  324,  325,  339,  340,  347,
#         354,  374,  381,  391,  396,  396,  400,  400,  442,  442,  451,
#         459,  467,  480,  480,  494,  515,  517,  544,  554,  554,  555,
#         555,  557,  557,  568,  584,  588,  591,  595,  608,  614,  636,
#         639,  649,  649,  651,  652,  652,  652,  672,  672,  684,  690,
#         690,  692,  692,  695,  723,  724,  730,  754,  776,  777,  795,
#         821,  832,  836,  837,  889,  899,  911,  917,  923,  925,  926,
#         982, 1017, 1018, 1043, 1051, 1051, 1071, 1074, 1079, 1079, 1081,
#        1081, 1111, 1114, 1131, 1154, 1165, 1175, 1186, 1231, 1235, 1244,
# ...

# %%
len(np.where(z>3)[0])
z.iloc[1017]
# Out:
# fixed acidity           0.183641
# volatile acidity        1.943091
# citric acid             0.508495
# residual sugar          1.162696
# chlorides               0.817557
# free sulfur dioxide     1.924577
# total sulfur dioxide    1.901540
# density                 3.538731
# pH                      2.728510
# sulphates               1.287363
# alcohol                 2.137373
# quality                 0.450848
# Name: 1017, dtype: float64

# %%
len(np.where(z>3)[0])
# Out:
# 192

# %%
df_new=df[(z<3).all (axis=1)]

# %%
df_new.shape
print(df_new.shape)
# Out:
# (1451, 12)

# %% [markdown]
# ## Percentage Data Loss

# %%
loss_percent=(1599-1451)/1599*100
print(loss_percent,"%")
# Out:
# 9.255784865540964 %

# %%
print('total_dropped_rows',df.shape[0]-df_new.shape[0])
# Out:
# total_dropped_rows 148

# %%
x=df_new.drop(['quality'], axis=1)
y=df_new.iloc[:,-1]

# %% [markdown]
# ## Data Transformation to remove skewness:

# %%
from sklearn.preprocessing import power_transform
x=power_transform(x,method='yeo-johnson')
x
# Out:
# array([[-0.46787818,  1.05573967, -1.52450588, ...,  1.36086042,
#         -0.58965734, -1.12042399],
#        [-0.17080535,  1.91974976, -1.52450588, ..., -0.81650738,
#          0.45152416, -0.5303401 ],
#        [-0.17080535,  1.35706712, -1.24543379, ..., -0.38097654,
#          0.22000451, -0.5303401 ],
#        ...,
#        [-1.45100718, -0.00286664, -0.66625579, ...,  0.74685493,
#          0.93043194,  0.74288203],
#        [-1.88546393,  0.76651828, -0.72755539, ...,  1.76243705,
#          0.666655  , -0.03416625],
#        [-1.7722373 , -1.33320495,  1.07130142, ...,  0.53899166,
#          0.29909273,  0.74288203]])

# %%
y
# Out:
# 0       5
# 1       5
# 2       5
# 3       6
# 4       5
#        ..
# 1594    5
# 1595    6
# 1596    6
# 1597    5
# 1598    6
# Name: quality, Length: 1451, dtype: int64

# %%
pd.DataFrame(x).skew()
# Out:
# 0     0.018666
# 1     0.004945
# 2     0.018049
# 3    -0.004606
# 4    -0.114658
# 5    -0.021455
# 6    -0.005813
# 7    -0.001043
# 8    -0.000074
# 9     0.020799
# 10    0.114658
# dtype: float64

# %% [markdown]
# ## Normal Distribution Curves

# %%
sns.distplot(x[0], color='green')
plt.title("fixed acidity")
plt.show()

# %%
sns.distplot(x[1], color='green')
plt.title("volatile acidity")
plt.show()

# %%
sns.distplot(x[2], color='green')
plt.title("citric acid")
plt.show()

# %%
sns.distplot(x[3], color='green')
plt.title("residual sugar")
plt.show()

# %%
sns.distplot(x[4], color='green')
plt.title("chlorides")
plt.show()

# %% [markdown]
# ## Reducing thedimensions

# %%
from sklearn.decomposition import PCA

# %%
pca=PCA(n_components=4)

# %%
pca.fit(x)
# Out:
# PCA(n_components=4)

# %%
x=pca.transform(x)

# %%
x.shape
# Out:
# (1451, 4)

# %%
x
# Out:
# array([[ 1.71155588e+00, -1.17175071e+00,  1.27881739e+00,
#         -1.97314634e-03],
#        [ 6.24701607e-01, -2.37211790e+00,  7.03970316e-02,
#          6.69339018e-01],
#        [ 5.74664889e-01, -1.57980052e+00,  5.06678468e-01,
#          3.98496192e-01],
#        ...,
#        [ 1.57422441e+00,  1.54037557e-02, -1.60471085e+00,
#          7.58678898e-01],
#        [ 2.67688597e+00, -6.25632152e-01, -1.33139782e+00,
#          4.49685693e-01],
#        [ 4.57074753e-01,  9.22318803e-01, -1.96723924e+00,
#          9.73413802e-01]])

# %% [markdown]
# ## Creating Model

# %%
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report

# %% [markdown]
# ## Spliting the Dataframe

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=48,test_size=0.20)

# %%
svc=SVC(kernel='linear')
svc.fit(x_train,y_train)
y_pred=svc.predict(x_test)
print("This is accuracy_score", accuracy_score(y_pred,y_test))
print("This is confusion_matrix",confusion_matrix(y_pred,y_test)) 
print("This is the classification_report",classification_report(y_pred,y_test))
# Out:
# This is accuracy_score 0.6048109965635738
# This is confusion_matrix [[  0   0   0   0   0]
#  [  9 104  44   2   0]
#  [  2  33  61  13   1]
#  [  1   2   7  11   1]
#  [  0   0   0   0   0]]
# This is the classification_report               precision    recall  f1-score   support
#
#            4       0.00      0.00      0.00         0
#            5       0.75      0.65      0.70       159
#            6       0.54      0.55      0.55       110
#            7       0.42      0.50      0.46        22
#            8       0.00      0.00      0.00         0
#
#     accuracy                           0.60       291
#    macro avg       0.34      0.34      0.34       291
# weighted avg       0.65      0.60      0.62       291

# %% [markdown]
# ## KNN (K_Nearest_Neighbors_Classifier)

# %%
kn=KNeighborsClassifier(n_neighbors=21)
kn.fit(x_train,y_train)
kn_pred=kn.predict(x_test)
print("This is accuracy_score", accuracy_score(kn_pred,y_test))
print("This is confusion_matrix",confusion_matrix(kn_pred,y_test)) 
print("This is the classification_report",classification_report(kn_pred,y_test))
# Out:
# This is accuracy_score 0.5738831615120275
# This is confusion_matrix [[ 0  0  0  0  0]
#  [ 9 97 43  1  0]
#  [ 3 36 63 18  1]
#  [ 0  6  6  7  1]
#  [ 0  0  0  0  0]]
# This is the classification_report               precision    recall  f1-score   support
#
#            4       0.00      0.00      0.00         0
#            5       0.70      0.65      0.67       150
#            6       0.56      0.52      0.54       121
#            7       0.27      0.35      0.30        20
#            8       0.00      0.00      0.00         0
#
#     accuracy                           0.57       291
#    macro avg       0.31      0.30      0.30       291
# weighted avg       0.61      0.57      0.59       291

# %% [markdown]
# ## Tuning the Model

# %%
pred_kn=kn.predict(x_test)
from sklearn.model_selection import cross_val_score
kn_score=accuracy_score(y_test,pred_kn)
for i in range(2,11):
    knscore=cross_val_score(kn,x,y,cv=i)
    knc=knscore.mean()
    print('at cv', i)
    print('cross_validation_score is:',knc*100)
    print('Accuracy_score is',kn_score*100)
    print("\n")
# Out:
# at cv 2
# cross_validation_score is: 54.10430322029068
# Accuracy_score is 57.388316151202744
#
#
# at cv 3
# cross_validation_score is: 53.48516218081435
# Accuracy_score is 57.388316151202744
#
#
# at cv 4
# cross_validation_score is: 52.5200523568178
# Accuracy_score is 57.388316151202744
#
#
# at cv 5
# cross_validation_score is: 53.621756132243156
# Accuracy_score is 57.388316151202744
#
#
# at cv 6
# cross_validation_score is: 53.00086874021238
# Accuracy_score is 57.388316151202744
#
#
# at cv 7
# cross_validation_score is: 52.31592079418166
# Accuracy_score is 57.388316151202744
#
#
# at cv 8
# cross_validation_score is: 52.94077469491833
# Accuracy_score is 57.388316151202744
#
#
# at cv 9
# cross_validation_score is: 53.41827910265913
# Accuracy_score is 57.388316151202744
#
#
# at cv 10
# cross_validation_score is: 53.553613604156816
# Accuracy_score is 57.388316151202744

# %% [markdown]
# # Roc_Auc score for model

# %%
from sklearn.metrics import roc_auc_score

# %%
kn_pred_proba=kn.predict_proba(x_test)

# %%
roc_auc_score(y_test,kn_pred_proba,multi_class='ovr')
# Out:
# 0.7630040200340544

# %% [markdown]
# ## Model saving

# %%
import pickle
filename='red_wine_model'
pickle.dump(kn,open(filename,'wb'))

# %% [markdown]
# ## Working ML Model for prediction

# %%
import numpy as np
a=np.array(y_test)
predicted=np.array(kn.predict(x_test))
df_wine=pd.DataFrame({'original':a,'predicted':predicted}, index=range(len(a)))
df_wine
# Out:
#      original  predicted
# 0           6          6
# 1           7          6
# 2           5          5
# 3           6          5
# 4           6          6
# ..        ...        ...
# 286         5          6
# 287         5          6
# 288         6          6
# 289         5          5
# 290         6          5
#
# [291 rows x 2 columns]
