# %% [markdown]
# # World Happiness Report

# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv(r'https://raw.githubusercontent.com/dsrscientist/DSData/master/happiness_score_dataset.csv')
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
df.head(10)
# Out:
#        Country                     Region  Happiness Rank  Happiness Score  \
# 0  Switzerland             Western Europe               1            7.587
# 1      Iceland             Western Europe               2            7.561
# 2      Denmark             Western Europe               3            7.527
# 3       Norway             Western Europe               4            7.522
# 4       Canada              North America               5            7.427
# 5      Finland             Western Europe               6            7.406
# 6  Netherlands             Western Europe               7            7.378
# 7       Sweden             Western Europe               8            7.364
# 8  New Zealand  Australia and New Zealand               9            7.286
# 9    Australia  Australia and New Zealand              10            7.284
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# ...

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %% [markdown]
# ## Data Explorattion

# %%
df['Country'].value_counts()
# Out:
# Switzerland    1
# Bangladesh     1
# Greece         1
# Lebanon        1
# Hungary        1
#               ..
# Kazakhstan     1
# Slovenia       1
# Lithuania      1
# Nicaragua      1
# Togo           1
# Name: Country, Length: 158, dtype: int64

# %%
  sns.distplot(df['Happiness Rank'], bins=20)
# Out:
# <AxesSubplot:xlabel='Happiness Rank', ylabel='Density'>

# %%
sns.violinplot(x='Happiness Score',data=df)
# Out:
# <AxesSubplot:xlabel='Happiness Score'>

# %%
sns.lmplot(x='Happiness Rank', y="Happiness Score", data=df)

# %% [markdown]
# Observations- More the happiness score more the happiness rank both are directly proportional

# %%
sns.scatterplot(x='Happiness Score', y='Standard Error',data=df,palette='deep',color='teal')
# Out:
# <AxesSubplot:xlabel='Happiness Score', ylabel='Standard Error'>

# %% [markdown]
# Observations- happpiness score is directly proportional standard error.

# %%
sns.scatterplot(x='Happiness Rank', y='Standard Error',data=df,palette='deep',color='teal')
# Out:
# <AxesSubplot:xlabel='Happiness Rank', ylabel='Standard Error'>

# %% [markdown]
# Observations- happpiness rank is directly proportional standard error.

# %%
sns.lmplot(x='Happiness Score', y='Economy (GDP per Capita)',data=df,palette='deep')

# %% [markdown]
# Observations- Both xx and y are directly proportional meaning increase in x will increase y as well

# %%
sns.regplot(x='Happiness Score', y='Family',data=df,robust=True)
# Out:
# <AxesSubplot:xlabel='Happiness Score', ylabel='Family'>

# %% [markdown]
# Observations- Incresing the family also leads to a positive increase in Happiness score

# %%
sns.scatterplot(x='Happiness Score', y='Health (Life Expectancy)',data=df)
# Out:
# <AxesSubplot:xlabel='Happiness Score', ylabel='Health (Life Expectancy)'>

# %% [markdown]
# Observations- x and y are directly proportional

# %%
sns.scatterplot(x='Happiness Score', y='Freedom',data=df)
# Out:
# <AxesSubplot:xlabel='Happiness Score', ylabel='Freedom'>

# %%
sns.scatterplot(x='Happiness Score', y='Trust (Government Corruption)',data=df)
# Out:
# <AxesSubplot:xlabel='Happiness Score', ylabel='Trust (Government Corruption)'>

# %%
sns.violinplot(x='Generosity',data=df, color='pink')
# Out:
# <AxesSubplot:xlabel='Generosity'>

# %% [markdown]
# Observations-20% people are generous

# %%
sns.regplot(x='Happiness Score', y='Dystopia Residual',data=df,robust=True)
# Out:
# <AxesSubplot:xlabel='Happiness Score', ylabel='Dystopia Residual'>

# %% [markdown]
# ## Correlation Matrix

# %%
df.corr()
# Out:
#                                Happiness Rank  Happiness Score  \
# Happiness Rank                       1.000000        -0.992105
# Happiness Score                     -0.992105         1.000000
# Standard Error                       0.158516        -0.177254
# Economy (GDP per Capita)            -0.785267         0.780966
# Family                              -0.733644         0.740605
# Health (Life Expectancy)            -0.735613         0.724200
# Freedom                             -0.556886         0.568211
# Trust (Government Corruption)       -0.372315         0.395199
# Generosity                          -0.160142         0.180319
# Dystopia Residual                   -0.521999         0.530474
#
#                                Standard Error  Economy (GDP per Capita)  \
# Happiness Rank                       0.158516                 -0.785267
# Happiness Score                     -0.177254                  0.780966
# ...

# %%
df.corr()["Happiness Score"].sort_values()
# Out:
# Happiness Rank                  -0.992105
# Standard Error                  -0.177254
# Generosity                       0.180319
# Trust (Government Corruption)    0.395199
# Dystopia Residual                0.530474
# Freedom                          0.568211
# Health (Life Expectancy)         0.724200
# Family                           0.740605
# Economy (GDP per Capita)         0.780966
# Happiness Score                  1.000000
# Name: Happiness Score, dtype: float64

# %% [markdown]
# ## Correlation Heatmap

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15,6))
sns.heatmap(df.corr(),annot= True, linewidths=0.5,linecolor='blue',fmt='2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Observations-
#
# Happiness Rank is -52% correlated to Happiness Score wwhich is very bad
#
# Standard Error is 8% correlated to Happiness Score which is bad
#
# Economy (GDP per Capita) is 4% correlated to Happiness Score which is bad
#
# Family is 15% correlated to Happiness Score wwhich is good
#
# Health (Life Expectancy) is 2% correlated to Happiness Score which is very bad
#
# Freedom is 6% correlated to Happiness Score which is bad
#
# Trust (Government Corruption) is -3% correlated to Happiness Score which is very bad
#
# Generosity is -10% correlated to Happiness Score wwhich is very bad
#
# Dystopia Residual is -10% correlated to Happiness Score wwhich is very bad

# %% [markdown]
# ## Data desscription

# %%
df.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %%
plt.figure(figsize=(15,7))
sns.heatmap(round(df.describe()[1:].transpose(),2), linewidth=1.5, fmt='f', annot= True)
plt.xticks(fontsize=18)
plt.yticks(fontsize=12)
plt.title('variable summary')
plt.show()

# %% [markdown]
# Observations-
#
# Happiness Rank-
#
# Mean=79.49000
# std=45.75
# min=1.000
# max=118.7500
#
# Standard Error-
#
# Mean=0.05000
# std=0.02000
# min=0.02000
# max=0.140000
#
# Economy (GDP per Capita)-
#
# Mean=0.85000
# std=0.27000
# min=0.000
# max=1.400000
#
# Family-
#
# Mean=0.99000
# std=0.27000
# min=0.000
# max=1.40000
#
# Health (Life Expectancy)-
#
# Mean=0.63
# std=0.15
# min=0.0000
# max=0.67000
#
# Freedom-
#
# Mean=0.43
# std=0.15
# min=0.0000
# max=1.030000
#
# Trust (Government Corruption)-
#
# Mean=0.14
# std=0.12
# min=0.0000
# max=0.55000
#
# Generosity-
#
# Mean=0.2400
# std=0.13000
# min=0.000
# max=0.8000
#
# Dystopia Residual-
#
# Mean=2.10000
# std=0.55000
# min=0.33000
# max=3.6000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %% [markdown]
# ## Outliers

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.preprocessing import LabelEncoder
for column in df:
    if df[column].dtypes == 'object':
        encoder = LabelEncoder()
        df[column] = encoder.fit_transform(df[column])
df
# Out:
#      Country  Region  Happiness Rank  Happiness Score  Standard Error  \
# 0        135       9               1            7.587         0.03411
# 1         58       9               2            7.561         0.04884
# 2         37       9               3            7.527         0.03328
# 3        105       9               4            7.522         0.03880
# 4         24       5               5            7.427         0.03553
# ..       ...     ...             ...              ...             ...
# 153      118       8             154            3.465         0.03464
# 154       13       8             155            3.340         0.03656
# 155      136       4             156            3.006         0.05015
# 156       21       8             157            2.905         0.08658
# 157      141       8             158            2.839         0.06727
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder
graph = 1
plt.figure(figsize=(10,10),facecolor='yellow')
for column in df:

    plt.subplot(4,3,graph)
    sns.boxplot(df[column],color='green',orient='v')
    plt.xlabel(column,fontsize=10)
    graph+=1
    plt.tight_layout()

# %% [markdown]
# Observations-
#
# outliers are present in Tust, Generosity, Dystopia Residual,Family, Standard Error.

# %% [markdown]
# ## Skewness in dataset

# %%
df.skew()
# Out:
# Country                          0.000000
# Region                          -0.116119
# Happiness Rank                   0.000418
# Happiness Score                  0.097769
# Standard Error                   1.983439
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    1.385463
# Generosity                       1.001961
# Dystopia Residual               -0.238911
# dtype: float64

# %% [markdown]
# Threshold value= +/-0.65
#
# skewness present-
#
# Standard error, Family, trust, Generosity

# %%
sns.distplot(df['Country'])
# Out:
# <AxesSubplot:xlabel='Country', ylabel='Density'>

# %%
sns.distplot(df['Region'])
# Out:
# <AxesSubplot:xlabel='Region', ylabel='Density'>

# %%
sns.distplot(df['Happiness Rank'])
# Out:
# <AxesSubplot:xlabel='Happiness Rank', ylabel='Density'>

# %%
sns.distplot(df['Standard Error'])
# Out:
# <AxesSubplot:xlabel='Standard Error', ylabel='Density'>

# %%
sns.distplot(df['Economy (GDP per Capita)'])
# Out:
# <AxesSubplot:xlabel='Economy (GDP per Capita)', ylabel='Density'>

# %%
sns.distplot(df['Family'])
# Out:
# <AxesSubplot:xlabel='Family', ylabel='Density'>

# %%
sns.distplot(df['Health (Life Expectancy)'])
# Out:
# <AxesSubplot:xlabel='Health (Life Expectancy)', ylabel='Density'>

# %%
sns.distplot(df['Freedom'])
# Out:
# <AxesSubplot:xlabel='Freedom', ylabel='Density'>

# %%
sns.distplot(df['Trust (Government Corruption)'])
# Out:
# <AxesSubplot:xlabel='Trust (Government Corruption)', ylabel='Density'>

# %%
sns.distplot(df['Generosity'])
# Out:
# <AxesSubplot:xlabel='Generosity', ylabel='Density'>

# %%
sns.distplot(df['Dystopia Residual'])
# Out:
# <AxesSubplot:xlabel='Dystopia Residual', ylabel='Density'>

# %% [markdown]
# ## Data Cleansing

# %%
df.corr()['Happiness Score']
# Out:
# Country                          0.083380
# Region                          -0.176791
# Happiness Rank                  -0.992105
# Happiness Score                  1.000000
# Standard Error                  -0.177254
# Economy (GDP per Capita)         0.780966
# Family                           0.740605
# Health (Life Expectancy)         0.724200
# Freedom                          0.568211
# Trust (Government Corruption)    0.395199
# Generosity                       0.180319
# Dystopia Residual                0.530474
# Name: Happiness Score, dtype: float64

# %% [markdown]
# ### Dropping the negatively correlated and highly skewed data columns

# %%
df.drop(['Standard Error'],axis=1,inplace=True)
df.head()
# Out:
#    Country  Region  Happiness Rank  Happiness Score  Economy (GDP per Capita)  \
# 0      135       9               1            7.587                   1.39651
# 1       58       9               2            7.561                   1.30232
# 2       37       9               3            7.527                   1.32548
# 3      105       9               4            7.522                   1.45900
# 4       24       5               5            7.427                   1.32629
#
#     Family  Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0  1.34951                   0.94143  0.66557                        0.41978
# 1  1.40223                   0.94784  0.62877                        0.14145
# 2  1.36058                   0.87464  0.64938                        0.48357
# 3  1.33095                   0.88521  0.66973                        0.36503
# 4  1.32261                   0.90563  0.63297                        0.32957
#
#    Generosity  Dystopia Residual
# ...

# %% [markdown]
# ## Data Encoding

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['Country']=le.fit_transform(df['Country'])
df['Region']=le.fit_transform(df['Region'])

# %% [markdown]
# ### Removing Outliers:

# %%
from scipy.stats import zscore
import numpy as np
z=np.abs(zscore(df))
z.shape
# Out:
# (158, 11)

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([ 27, 128, 147, 153, 155, 157], dtype=int64), array([ 8,  9,  5,  8, 10,  5], dtype=int64))

# %%
len(np.where(z>3)[0])
# Out:
# 6

# %%
z.iloc[155]
# Out:
# Country                          1.260695
# Region                           0.375441
# Happiness Rank                   1.677427
# Happiness Score                  2.076199
# Economy (GDP per Capita)         0.455245
# Family                           1.901086
# Health (Life Expectancy)         0.372199
# Freedom                          1.809238
# Trust (Government Corruption)    0.381419
# Generosity                       1.856891
# Dystopia Residual                3.208430
# Name: 155, dtype: float64

# %% [markdown]
# Dystopia Residual has maximum number of outtliers

# %%
df_new=df[(z<3).all(axis=1)]
print("old DataFrame",df.shape)
print("New DataFrame",df_new.shape)
print("total_dropped_rows",df.shape[0]-df_new.shape[0])
# Out:
# old DataFrame (158, 11)
# New DataFrame (152, 11)
# total_dropped_rows 6

# %%
loss_percent=(158-152)/158*100
print(loss_percent,"%")
# Out:
# 3.79746835443038 %

# %%
x=df_new.drop(["Happiness Score"],axis=1)
y=df_new.iloc[:,3]

# %% [markdown]
# ## Removing Skewness

# %%
from sklearn.preprocessing import power_transform
x=power_transform(x,method='yeo-johnson')
x
# Out:
# array([[ 1.1887051 ,  1.23986819, -2.06118488, ...,  1.8220699 ,
#          0.65595135,  0.74453432],
#        [-0.31421047,  1.23986819, -2.00536253, ...,  0.35523024,
#          1.57166845,  1.10426166],
#        [-0.81704158,  1.23986819, -1.95460445, ...,  1.95457489,
#          0.97742359,  0.69531125],
#        ...,
#        [-2.10859031,  0.67236186,  1.5407485 , ..., -0.16357633,
#          1.13659521, -0.34441601],
#        [-1.51998719,  0.96090613,  1.57594638, ..., -0.40394411,
#         -0.32359556, -0.94945138],
#        [-1.26108344,  0.96090613,  1.61101853, ..., -0.11827784,
#         -0.18319784, -0.57122297]])

# %%
pd.DataFrame(x).skew()
# Out:
# 0   -0.267218
# 1   -0.216720
# 2   -0.261914
# 3   -0.144167
# 4   -0.149268
# 5   -0.184207
# 6   -0.077878
# 7    0.179115
# 8    0.022444
# 9    0.014422
# dtype: float64

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)
x
# Out:
# array([[ 1.1887051 ,  1.23986819, -2.06118488, ...,  1.8220699 ,
#          0.65595135,  0.74453432],
#        [-0.31421047,  1.23986819, -2.00536253, ...,  0.35523024,
#          1.57166845,  1.10426166],
#        [-0.81704158,  1.23986819, -1.95460445, ...,  1.95457489,
#          0.97742359,  0.69531125],
#        ...,
#        [-2.10859031,  0.67236186,  1.5407485 , ..., -0.16357633,
#          1.13659521, -0.34441601],
#        [-1.51998719,  0.96090613,  1.57594638, ..., -0.40394411,
#         -0.32359556, -0.94945138],
#        [-1.26108344,  0.96090613,  1.61101853, ..., -0.11827784,
#         -0.18319784, -0.57122297]])

# %% [markdown]
# ## Creating a best fit ML Model for prediction

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.ensemble import AdaBoostRegressor

# %% [markdown]
# ## Spliting the Dataframe

# %% [markdown]
# ## creating and training the model

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=49,test_size=0.20)
lr= LinearRegression()
lr.fit(x_train,y_train)
pred=lr.predict(x_test)
print("result from Linear Regresssion Model")
print("R2 score is",r2_score(pred,y_test))
print("mean_squared_error",mean_squared_error(pred,y_test))
# Out:
# result from Linear Regresssion Model
# R2 score is 0.9973801392815617
# mean_squared_error 0.003427586039453946

# %%
x_train.shape
# Out:
# (121, 10)

# %%
x_test.shape
# Out:
# (31, 10)

# %%
y_train.shape
# Out:
# (121,)

# %%
y_test.shape
# Out:
# (31,)

# %% [markdown]
# Thus our model has an accuracy of 99%

# %%
rf=RandomForestRegressor(n_estimators=1000)
rf.fit(x_train,y_train)
pred=rf.predict(x_test)
print('result from random_forestregressor')
print('R2 score is',r2_score(pred,y_test))
print('mean_squared_error',mean_squared_error(pred,y_test))
# Out:
# result from random_forestregressor
# R2 score is 0.9985816408634172
# mean_squared_error 0.0017994461728707092

# %%
ab= AdaBoostRegressor()
ab.fit(x_train,y_train)
pred=ab.predict(x_test)
print('Result from AdaBoostRegressor')
print('R2 score is',r2_score(pred,y_test))
print('mean_squared_error',mean_squared_error(pred,y_test))
# Out:
# Result from AdaBoostRegressor
# R2 score is 0.9974181344668978
# mean_squared_error 0.0031391614459605967

# %% [markdown]
# ## Model_scores of linear regression, raandom forest,adaboost regressor

# %%
reg=lr.score(x_train,y_train)
rand=rf.score(x_train,y_train)
ada=ab.score(x_train,y_train)

print(reg)
print(rand)
print(ada)
# Out:
# 0.9957646902096267
# 0.9992835644787927
# 0.9980663788050403

# %% [markdown]
# ## Tuning the Model

# %% [markdown]
# ### using k- Fold cross-validation technique

# %%
pred_rf=rf.predict(x_test)
from sklearn.model_selection import cross_val_score
lrf=r2_score(y_test,pred_rf)
for i in range(2,10):
    lrfscore=cross_val_score(rf,x,y,cv=i)
    lrfs=lrfscore.mean()
    print('at cv', i)
    print('cross_validation_score is:',lrfs*100)
    print('R2 score is',lrf*100)
    print("\n")
# Out:
# at cv 2
# cross_validation_score is: -283.1124028575669
# R2 score is 99.85868762574282
#
#
# at cv 3
# cross_validation_score is: -158.09996183774467
# R2 score is 99.85868762574282
#
#
# at cv 4
# cross_validation_score is: -210.45376059047976
# R2 score is 99.85868762574282
#
#
# at cv 5
# cross_validation_score is: -168.91420006914643
# R2 score is 99.85868762574282
#
#
# at cv 6
# cross_validation_score is: -164.3252342591388
# R2 score is 99.85868762574282
#
#
# at cv 7
# cross_validation_score is: -227.0752835891471
# R2 score is 99.85868762574282
#
#
# at cv 8
# cross_validation_score is: -194.5904507680977
# R2 score is 99.85868762574282
#
#
# at cv 9
# cross_validation_score is: -179.25393970809074
# R2 score is 99.85868762574282

# %% [markdown]
# ### Selection of validation score from CV

# %%
lrfscore_selected=cross_val_score(rf,x,y,cv=5).mean()
print('CV score is',lrfscore_selected,"\n accuracy_score is",lrfs)
# Out:
# CV score is -1.683020526530538
#  accuracy_score is -1.7925393970809074

# %% [markdown]
# ### Saving the Model- Pickkle

# %%
import pickle
filename='world_happiness_report'
pickle.dump(rf,open(filename,'wb'))

# %% [markdown]
# ### Working mL Model for prediction

# %%
import numpy as np
a=np.array(y_test)
predicted=np.array(rf.predict(x_test))
df_com=pd.DataFrame({'original':a,'predicted':predicted}, index=range(len(a)))
df_com
# Out:
#     original  predicted
# 0      4.677   4.661302
# 1      3.819   3.791052
# 2      5.848   5.845947
# 3      5.192   5.201115
# 4      5.268   5.246406
# 5      5.129   5.149528
# 6      3.904   3.892346
# 7      4.297   4.246591
# 8      5.098   5.079808
# 9      5.073   5.050679
# 10     4.633   4.597868
# 11     4.800   4.804864
# 12     6.505   6.510223
# 13     4.436   4.423852
# 14     7.527   7.468290
# 15     4.715   4.712508
# 16     4.350   4.315774
# 17     4.252   4.219531
# 18     3.781   3.719801
# 19     3.995   3.959866
# 20     4.681   4.678076
# 21     6.940   6.919895
# 22     6.901   6.854883
# 23     6.798   6.818787
# 24     5.102   5.130769
# 25     7.561   7.452787
# 26     3.667   3.544449
# 27     5.975   5.963039
# 28     4.507   4.501023
# 29     6.937   6.856650
# 30     5.474   5.442062

# %% [markdown]
# predicted values are almost same so we can deploy the model

# %%
model=df_com.to_excel('happiness_report.xlsx')
